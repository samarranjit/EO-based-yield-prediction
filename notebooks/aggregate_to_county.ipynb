# %% [markdown]
# ## Aggregate the yield back to county level and compare with NASS yield

# %%
actual_pred = "actual"
for state in ['IA', 'IL', 'IN', 'MN','MD']:
    # !uv run python /home/cholab/LabMembers/Samar/EO-based-yield-prediction/model/scripts/county_aggregate.py --raster "/home/cholab/LabMembers/Samar/EO-based-yield-prediction/model/outputs/predictions/cornbelt_5_longer_years_009/soybeans_{state}_2024_{actual_pred}.tif" --state {state} --year 2024 --plot
# Out:
# ...
# raster   : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/model/outputs/predictions/cornbelt_5_longer_years_009/soybeans_IA_2024_actual.tif
# state    : IA   year: 2024   units: bu_ac
#
# counties with raster pixels : 96
#   of which matched to NASS  : 68
#   below --min-pixels (100)   : 28  (excluded from the summary)
#
# [mean vs NASS]  n=68 counties, equally weighted
#   bias   +0.007   MAE   0.009   RMSE   0.025
#   R2     1.0000   r    1.0000   max|diff| 0.172
#
# [median vs NASS]  n=68 counties, equally weighted
#   bias   +0.246   MAE   0.259   RMSE   0.306
#   R2     0.9952   r    0.9994   max|diff| 0.755
#
# largest county disagreements (mean - NASS):
#   19135.0  Monroe             raster   56.47  nass   56.30  diff   +0.17 (113,941 px)
#   19053.0  Decatur            raster   51.26  nass   51.20  diff   +0.06 (173,368 px)
#   19097.0  Jackson            raster   64.65  nass   64.60  diff   +0.05 (259,213 px)
# ...
