# %%
from pathlib import Path
import sys

# %%
parent_folder = Path("/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff")
tif_files = sorted(
    parent_folder.glob(
        f"soybeans_MD_2022_*.tif"
    )
)

# %%
tif_files
# Out:
# [PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24001_Allegany_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24003_Anne_Arundel_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24005_Baltimore_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24009_Calvert_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24011_Caroline_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24013_Carroll_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24015_Cecil_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24017_Charles_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24019_Dorchester_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24021_Frederick_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24023_Garrett_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24025_Harford_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24027_Howard_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24029_Kent_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24031_Montgomery_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24033_Prince_Georges_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24035_Queen_Annes_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24037_St_Marys_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24039_Somerset_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24041_Talbot_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24043_Washington_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24045_Wicomico_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24047_Worcester_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/Maryland/VI_tiff/soybeans_MD_2022_24510_Baltimore_vi_pixels_nasa_cmr_hls.tif')]

# %%
len(tif_files)
# Out:
# 24

# %%
for tif_file in tif_files:
    # !uv run python /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/scripts/distribute_county_yield_to_pixels.py --vi-tif-path {tif_file}
# Out:
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24001_Allegany_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24001
#   County name : Allegany
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1365, 1962)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 2,248
#   Valid VI pixels   : 2,248
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24001: 'No NASS yield found for GEOID=24001, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24001_Allegany_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24001_Allegany_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24003_Anne_Arundel_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24003
#   County name : Anne
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1890, 1317)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 26,224
#   Valid VI pixels   : 26,224
#
# Found 1 county/county-like IDs in raster.
# Processing county 24003: NASS=40.00 bu/ac, valid VI pixels=26,224, crop pixels=26,224
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24003_Anne_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24003_Anne_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24003  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24003_Anne_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24005_Baltimore_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24005
#   County name : Baltimore
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1936, 1703)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 55,905
#   Valid VI pixels   : 55,905
#
# Found 1 county/county-like IDs in raster.
# Processing county 24005: NASS=48.70 bu/ac, valid VI pixels=55,905, crop pixels=55,905
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24005_Baltimore_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24005_Baltimore_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24005  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24005_Baltimore_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24009_Calvert_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24009
#   County name : Calvert
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1552, 1155)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 17,782
#   Valid VI pixels   : 17,782
#
# Found 1 county/county-like IDs in raster.
# Processing county 24009: NASS=38.00 bu/ac, valid VI pixels=17,782, crop pixels=17,782
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24009_Calvert_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24009_Calvert_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24009  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24009_Calvert_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24011_Caroline_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24011
#   County name : Caroline
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1834, 938)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 181,841
#   Valid VI pixels   : 181,718
#
# Found 1 county/county-like IDs in raster.
# Processing county 24011: NASS=42.20 bu/ac, valid VI pixels=181,718, crop pixels=181,841
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24011_Caroline_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24011_Caroline_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24011  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24011_Caroline_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24013_Carroll_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24013
#   County name : Carroll
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1569, 1430)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 124,169
#   Valid VI pixels   : 124,169
#
# Found 1 county/county-like IDs in raster.
# Processing county 24013: NASS=43.00 bu/ac, valid VI pixels=124,169, crop pixels=124,169
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24013_Carroll_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24013_Carroll_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24013  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24013_Carroll_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24015_Cecil_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24015
#   County name : Cecil
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1414, 1565)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 89,797
#   Valid VI pixels   : 89,791
#
# Found 1 county/county-like IDs in raster.
# Processing county 24015: NASS=47.20 bu/ac, valid VI pixels=89,791, crop pixels=89,797
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24015_Cecil_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24015_Cecil_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24015  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24015_Cecil_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24017_Charles_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24017
#   County name : Charles
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1515, 1696)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 47,694
#   Valid VI pixels   : 47,694
#
# Found 1 county/county-like IDs in raster.
# Processing county 24017: NASS=37.30 bu/ac, valid VI pixels=47,694, crop pixels=47,694
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24017_Charles_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24017_Charles_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24017  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24017_Charles_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24019_Dorchester_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24019
#   County name : Dorchester
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2304, 1722)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 208,788
#   Valid VI pixels   : 208,757
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24019: 'No NASS yield found for GEOID=24019, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24019_Dorchester_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24019_Dorchester_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24021_Frederick_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24021
#   County name : Frederick
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1966, 1475)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 164,668
#   Valid VI pixels   : 164,666
#
# Found 1 county/county-like IDs in raster.
# Processing county 24021: NASS=45.30 bu/ac, valid VI pixels=164,666, crop pixels=164,668
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24021_Frederick_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24021_Frederick_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24021  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24021_Frederick_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24023_Garrett_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24023
#   County name : Garrett
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2188, 1528)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 7,987
#   Valid VI pixels   : 7,987
#
# Found 1 county/county-like IDs in raster.
# Processing county 24023: NASS=41.90 bu/ac, valid VI pixels=7,987, crop pixels=7,987
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24023_Garrett_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24023_Garrett_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24023  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24023_Garrett_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24025_Harford_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24025
#   County name : Harford
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1657, 1623)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 62,107
#   Valid VI pixels   : 62,107
#
# Found 1 county/county-like IDs in raster.
# Processing county 24025: NASS=49.70 bu/ac, valid VI pixels=62,107, crop pixels=62,107
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24025_Harford_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24025_Harford_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24025  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24025_Harford_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24027_Howard_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24027
#   County name : Howard
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (891, 1464)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 20,065
#   Valid VI pixels   : 20,065
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24027: 'No NASS yield found for GEOID=24027, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24027_Howard_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24027_Howard_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24029_Kent_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24029
#   County name : Kent
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1622, 1384)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 166,709
#   Valid VI pixels   : 166,698
#
# Found 1 county/county-like IDs in raster.
# Processing county 24029: NASS=44.70 bu/ac, valid VI pixels=166,698, crop pixels=166,709
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24029_Kent_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24029_Kent_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24029  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24029_Kent_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24031_Montgomery_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24031
#   County name : Montgomery
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1509, 1800)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 58,065
#   Valid VI pixels   : 58,065
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24031: 'No NASS yield found for GEOID=24031, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24031_Montgomery_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24031_Montgomery_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24033_Prince_Georges_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24033
#   County name : Prince
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2063, 1285)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 23,696
#   Valid VI pixels   : 23,696
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24033: 'No NASS yield found for GEOID=24033, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24033_Prince_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24033_Prince_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24035_Queen_Annes_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24035
#   County name : Queen
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1867, 1559)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 230,126
#   Valid VI pixels   : 230,085
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24035: 'No NASS yield found for GEOID=24035, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24035_Queen_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24035_Queen_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24037_St_Marys_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24037
#   County name : St
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1499, 1827)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 69,391
#   Valid VI pixels   : 69,391
#
# Found 1 county/county-like IDs in raster.
# Processing county 24037: NASS=41.80 bu/ac, valid VI pixels=69,391, crop pixels=69,391
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24037_St_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24037_St_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24037  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24037_St_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24039_Somerset_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24039
#   County name : Somerset
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1550, 1461)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 77,466
#   Valid VI pixels   : 77,431
#
# Found 1 county/county-like IDs in raster.
# Processing county 24039: NASS=37.20 bu/ac, valid VI pixels=77,431, crop pixels=77,466
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24039_Somerset_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24039_Somerset_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24039  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24039_Somerset_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24041_Talbot_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24041
#   County name : Talbot
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1327, 1353)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 167,914
#   Valid VI pixels   : 167,904
#
# Found 1 county/county-like IDs in raster.
# Processing county 24041: NASS=43.70 bu/ac, valid VI pixels=167,904, crop pixels=167,914
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24041_Talbot_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24041_Talbot_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24041  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24041_Talbot_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24043_Washington_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24043
#   County name : Washington
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1602, 2447)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 63,803
#   Valid VI pixels   : 63,803
#
# Found 1 county/county-like IDs in raster.
# Processing county 24043: NASS=52.50 bu/ac, valid VI pixels=63,803, crop pixels=63,803
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24043_Washington_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24043_Washington_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24043  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24043_Washington_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24045_Wicomico_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24045
#   County name : Wicomico
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1334, 1659)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 143,187
#   Valid VI pixels   : 143,073
#
# Found 1 county/county-like IDs in raster.
# Processing county 24045: NASS=37.40 bu/ac, valid VI pixels=143,073, crop pixels=143,187
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24045_Wicomico_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24045_Wicomico_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24045  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24045_Wicomico_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24047_Worcester_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24047
#   County name : Worcester
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2027, 1465)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 165,419
#   Valid VI pixels   : 165,333
#
# Found 1 county/county-like IDs in raster.
# Processing county 24047: NASS=39.20 bu/ac, valid VI pixels=165,333, crop pixels=165,419
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24047_Worcester_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24047_Worcester_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       24047  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24047_Worcester_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_MD_2022_24510_Baltimore_vi_pixels_nasa_cmr_hls.tif
#   State       : MD
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 24510
#   County name : Baltimore
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (653, 623)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 63
#   Valid VI pixels   : 63
#
# Found 1 county/county-like IDs in raster.
# Skipping county 24510: 'No NASS yield found for GEOID=24510, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24510_Baltimore_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_MD_2022_24510_Baltimore_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
