# %%
from pathlib import Path
import sys

# %%
STATE_CODE = "IA"
YEAR = 2022

# %%
parent_folder = Path(f"/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/{STATE_CODE}")

# %%
tif_files = sorted(
    parent_folder.glob(
        f"soybeans_{STATE_CODE}_{YEAR}_*.tif"
    )
)

# %%
tif_files
# Out:
# [PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19001_Adair_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19003_Adams_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19005_Allamakee_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19007_Appanoose_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19009_Audubon_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19011_Benton_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19013_Black_Hawk_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19015_Boone_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19017_Bremer_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19019_Buchanan_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19021_Buena_Vista_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19023_Butler_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19025_Calhoun_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19027_Carroll_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19029_Cass_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19031_Cedar_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19033_Cerro_Gordo_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19035_Cherokee_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19037_Chickasaw_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19039_Clarke_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19041_Clay_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19043_Clayton_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19045_Clinton_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19047_Crawford_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19049_Dallas_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19051_Davis_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19053_Decatur_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19055_Delaware_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19057_Des_Moines_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19059_Dickinson_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19061_Dubuque_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19063_Emmet_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19065_Fayette_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19067_Floyd_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19069_Franklin_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19071_Fremont_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19073_Greene_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19075_Grundy_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19077_Guthrie_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19079_Hamilton_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19081_Hancock_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19083_Hardin_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19085_Harrison_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19087_Henry_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19089_Howard_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19091_Humboldt_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19093_Ida_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19095_Iowa_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19097_Jackson_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19099_Jasper_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19101_Jefferson_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19103_Johnson_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19105_Jones_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19107_Keokuk_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19109_Kossuth_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19111_Lee_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19113_Linn_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19115_Louisa_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19117_Lucas_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19119_Lyon_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19121_Madison_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19123_Mahaska_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19125_Marion_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19127_Marshall_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19129_Mills_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19131_Mitchell_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19133_Monona_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19135_Monroe_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19137_Montgomery_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19139_Muscatine_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19141_OBrien_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19143_Osceola_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19145_Page_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19147_Palo_Alto_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19149_Plymouth_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19151_Pocahontas_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19153_Polk_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19155_Pottawattamie_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19157_Poweshiek_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19159_Ringgold_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19161_Sac_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19163_Scott_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19165_Shelby_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19167_Sioux_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19169_Story_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19171_Tama_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19173_Taylor_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19175_Union_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19177_Van_Buren_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19179_Wapello_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19181_Warren_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19183_Washington_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19185_Wayne_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19187_Webster_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19189_Winnebago_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19191_Winneshiek_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19193_Woodbury_vi_pixels_nasa_cmr_hls.tif'),
#  PosixPath('/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/IA/soybeans_IA_2022_19195_Worth_vi_pixels_nasa_cmr_hls.tif')]

# %%
len(tif_files)
# Out:
# 98

# %%
for tif_file in tif_files:
    # !uv run python /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/scripts/distribute_county_yield_to_pixels.py --vi-tif-path {tif_file}
# Out:
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19001_Adair_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19001
#   County name : Adair
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1311, 1292)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 492,403
#   Valid VI pixels   : 492,403
#
# Found 1 county/county-like IDs in raster.
# Processing county 19001: NASS=47.50 bu/ac, valid VI pixels=492,403, crop pixels=492,403
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19001_Adair_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19001_Adair_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19001  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19001_Adair_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19003_Adams_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19003
#   County name : Adams
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (977, 1284)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 325,137
#   Valid VI pixels   : 325,137
#
# Found 1 county/county-like IDs in raster.
# Skipping county 19003: 'No NASS yield found for GEOID=19003, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19003_Adams_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19003_Adams_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19005_Allamakee_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19005
#   County name : Allamakee
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1609, 1531)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 141,590
#   Valid VI pixels   : 141,590
#
# Found 1 county/county-like IDs in raster.
# Processing county 19005: NASS=61.20 bu/ac, valid VI pixels=141,590, crop pixels=141,590
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19005_Allamakee_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19005_Allamakee_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19005  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19005_Allamakee_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19007_Appanoose_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19007
#   County name : Appanoose
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1218, 1321)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 192,908
#   Valid VI pixels   : 192,908
#
# Found 1 county/county-like IDs in raster.
# Processing county 19007: NASS=40.40 bu/ac, valid VI pixels=192,908, crop pixels=192,908
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19007_Appanoose_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19007_Appanoose_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19007  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19007_Appanoose_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19009_Audubon_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19009
#   County name : Audubon
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1345, 1097)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 445,008
#   Valid VI pixels   : 445,008
#
# Found 1 county/county-like IDs in raster.
# Processing county 19009: NASS=57.90 bu/ac, valid VI pixels=445,008, crop pixels=445,008
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19009_Audubon_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19009_Audubon_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19009  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19009_Audubon_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19011_Benton_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19011
#   County name : Benton
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1679, 1348)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 697,020
#   Valid VI pixels   : 697,020
#
# Found 1 county/county-like IDs in raster.
# Processing county 19011: NASS=66.10 bu/ac, valid VI pixels=697,020, crop pixels=697,020
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19011_Benton_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19011_Benton_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19011  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19011_Benton_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19013_Black_Hawk_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19013
#   County name : Black
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1334, 1384)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 454,231
#   Valid VI pixels   : 454,231
#
# Found 1 county/county-like IDs in raster.
# Processing county 19013: NASS=64.50 bu/ac, valid VI pixels=454,231, crop pixels=454,231
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19013_Black_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19013_Black_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19013  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19013_Black_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19015_Boone_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19015
#   County name : Boone
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1319, 1308)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 503,293
#   Valid VI pixels   : 503,293
#
# Found 1 county/county-like IDs in raster.
# Processing county 19015: NASS=60.40 bu/ac, valid VI pixels=503,293, crop pixels=503,293
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19015_Boone_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19015_Boone_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19015  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19015_Boone_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19017_Bremer_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19017
#   County name : Bremer
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1036, 1320)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 342,691
#   Valid VI pixels   : 342,691
#
# Found 1 county/county-like IDs in raster.
# Processing county 19017: NASS=66.70 bu/ac, valid VI pixels=342,691, crop pixels=342,691
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19017_Bremer_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19017_Bremer_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19017  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19017_Bremer_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19019_Buchanan_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19019
#   County name : Buchanan
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1346, 1376)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 449,999
#   Valid VI pixels   : 449,999
#
# Found 1 county/county-like IDs in raster.
# Processing county 19019: NASS=65.00 bu/ac, valid VI pixels=449,999, crop pixels=449,999
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19019_Buchanan_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19019_Buchanan_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19019  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19019_Buchanan_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19021_Buena_Vista_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19021
#   County name : Buena
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1311, 1298)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 650,133
#   Valid VI pixels   : 650,130
#
# Found 1 county/county-like IDs in raster.
# Processing county 19021: NASS=57.20 bu/ac, valid VI pixels=650,130, crop pixels=650,133
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19021_Buena_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19021_Buena_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19021  ...              -1.421085e-14
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19021_Buena_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19023_Butler_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19023
#   County name : Butler
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1349, 1322)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 481,378
#   Valid VI pixels   : 481,375
#
# Found 1 county/county-like IDs in raster.
# Processing county 19023: NASS=61.60 bu/ac, valid VI pixels=481,375, crop pixels=481,378
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19023_Butler_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19023_Butler_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19023  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19023_Butler_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19025_Calhoun_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19025
#   County name : Calhoun
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1318, 1429)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 613,750
#   Valid VI pixels   : 613,748
#
# Found 1 county/county-like IDs in raster.
# Processing county 19025: NASS=61.20 bu/ac, valid VI pixels=613,748, crop pixels=613,750
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19025_Calhoun_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19025_Calhoun_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19025  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19025_Calhoun_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19027_Carroll_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19027
#   County name : Carroll
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1306, 1283)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 550,528
#   Valid VI pixels   : 550,528
#
# Found 1 county/county-like IDs in raster.
# Processing county 19027: NASS=58.90 bu/ac, valid VI pixels=550,528, crop pixels=550,528
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19027_Carroll_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19027_Carroll_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19027  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19027_Carroll_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19029_Cass_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19029
#   County name : Cass
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1302, 1275)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 553,885
#   Valid VI pixels   : 553,885
#
# Found 1 county/county-like IDs in raster.
# Processing county 19029: NASS=51.20 bu/ac, valid VI pixels=553,885, crop pixels=553,885
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19029_Cass_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19029_Cass_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19029  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19029_Cass_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19031_Cedar_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19031
#   County name : Cedar
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1362, 1348)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 543,884
#   Valid VI pixels   : 543,884
#
# Found 1 county/county-like IDs in raster.
# Processing county 19031: NASS=67.00 bu/ac, valid VI pixels=543,884, crop pixels=543,884
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19031_Cedar_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19031_Cedar_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19031  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19031_Cedar_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19033_Cerro_Gordo_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19033
#   County name : Cerro
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1329, 1313)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 501,673
#   Valid VI pixels   : 501,673
#
# Found 1 county/county-like IDs in raster.
# Processing county 19033: NASS=60.80 bu/ac, valid VI pixels=501,673, crop pixels=501,673
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19033_Cerro_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19033_Cerro_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19033  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19033_Cerro_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19035_Cherokee_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19035
#   County name : Cherokee
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1307, 1288)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 604,533
#   Valid VI pixels   : 604,523
#
# Found 1 county/county-like IDs in raster.
# Processing county 19035: NASS=59.60 bu/ac, valid VI pixels=604,523, crop pixels=604,533
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19035_Cherokee_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19035_Cherokee_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19035  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19035_Cherokee_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19037_Chickasaw_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19037
#   County name : Chickasaw
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1188, 1321)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 401,065
#   Valid VI pixels   : 401,065
#
# Found 1 county/county-like IDs in raster.
# Processing county 19037: NASS=63.60 bu/ac, valid VI pixels=401,065, crop pixels=401,065
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19037_Chickasaw_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19037_Chickasaw_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19037  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19037_Chickasaw_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19039_Clarke_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19039
#   County name : Clarke
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1017, 1296)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 163,382
#   Valid VI pixels   : 163,382
#
# Found 1 county/county-like IDs in raster.
# Processing county 19039: NASS=40.20 bu/ac, valid VI pixels=163,382, crop pixels=163,382
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19039_Clarke_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19039_Clarke_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19039  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19039_Clarke_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19041_Clay_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19041
#   County name : Clay
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1298, 1293)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 546,836
#   Valid VI pixels   : 546,836
#
# Found 1 county/county-like IDs in raster.
# Processing county 19041: NASS=56.90 bu/ac, valid VI pixels=546,836, crop pixels=546,836
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19041_Clay_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19041_Clay_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19041  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19041_Clay_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19043_Clayton_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19043
#   County name : Clayton
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1681, 1997)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 286,560
#   Valid VI pixels   : 286,560
#
# Found 1 county/county-like IDs in raster.
# Processing county 19043: NASS=64.50 bu/ac, valid VI pixels=286,560, crop pixels=286,560
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19043_Clayton_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19043_Clayton_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19043  ...               1.421085e-14
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19043_Clayton_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19045_Clinton_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19045
#   County name : Clinton
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1202, 2083)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 551,342
#   Valid VI pixels   : 551,342
#
# Found 1 county/county-like IDs in raster.
# Processing county 19045: NASS=66.00 bu/ac, valid VI pixels=551,342, crop pixels=551,342
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19045_Clinton_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19045_Clinton_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19045  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19045_Clinton_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19047_Crawford_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19047
#   County name : Crawford
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1307, 1595)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 662,585
#   Valid VI pixels   : 662,584
#
# Found 1 county/county-like IDs in raster.
# Processing county 19047: NASS=62.80 bu/ac, valid VI pixels=662,584, crop pixels=662,585
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19047_Crawford_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19047_Crawford_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19047  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19047_Crawford_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19049_Dallas_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19049
#   County name : Dallas
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1367, 1377)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 455,241
#   Valid VI pixels   : 455,196
#
# Found 1 county/county-like IDs in raster.
# Processing county 19049: NASS=59.80 bu/ac, valid VI pixels=455,196, crop pixels=455,241
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19049_Dallas_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19049_Dallas_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19049  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19049_Dallas_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19051_Davis_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19051
#   County name : Davis
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1201, 1324)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 222,527
#   Valid VI pixels   : 222,527
#
# Found 1 county/county-like IDs in raster.
# Processing county 19051: NASS=44.60 bu/ac, valid VI pixels=222,527, crop pixels=222,527
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19051_Davis_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19051_Davis_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19051  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19051_Davis_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19053_Decatur_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19053
#   County name : Decatur
#
# ...
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19179_Wapello_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19179
#   County name : Wapello
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1033, 1319)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 242,033
#   Valid VI pixels   : 242,033
#
# Found 1 county/county-like IDs in raster.
# Processing county 19179: NASS=53.70 bu/ac, valid VI pixels=242,033, crop pixels=242,033
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19179_Wapello_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19179_Wapello_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19179  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19179_Wapello_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19181_Warren_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19181
#   County name : Warren
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1331, 1315)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 292,627
#   Valid VI pixels   : 292,624
#
# Found 1 county/county-like IDs in raster.
# Processing county 19181: NASS=50.20 bu/ac, valid VI pixels=292,624, crop pixels=292,627
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19181_Warren_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19181_Warren_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19181  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19181_Warren_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19183_Washington_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19183
#   County name : Washington
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1349, 1332)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 429,554
#   Valid VI pixels   : 429,553
#
# Found 1 county/county-like IDs in raster.
# Processing county 19183: NASS=57.20 bu/ac, valid VI pixels=429,553, crop pixels=429,554
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19183_Washington_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19183_Washington_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19183  ...               7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19183_Washington_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19185_Wayne_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19185
#   County name : Wayne
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1225, 1315)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 296,658
#   Valid VI pixels   : 296,658
#
# Found 1 county/county-like IDs in raster.
# Skipping county 19185: 'No NASS yield found for GEOID=19185, year=2022'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19185_Wayne_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19185_Wayne_pseudo_yield_county_diagnostics.csv
# No finite pseudo-yield values available for plotting.
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19187_Webster_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19187
#   County name : Webster
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1646, 1426)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 710,288
#   Valid VI pixels   : 710,285
#
# Found 1 county/county-like IDs in raster.
# Processing county 19187: NASS=57.50 bu/ac, valid VI pixels=710,285, crop pixels=710,288
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19187_Webster_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19187_Webster_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19187  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19187_Webster_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19189_Winnebago_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19189
#   County name : Winnebago
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (939, 1295)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 390,383
#   Valid VI pixels   : 390,383
#
# Found 1 county/county-like IDs in raster.
# Processing county 19189: NASS=64.40 bu/ac, valid VI pixels=390,383, crop pixels=390,383
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19189_Winnebago_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19189_Winnebago_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19189  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19189_Winnebago_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19191_Winneshiek_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19191
#   County name : Winneshiek
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1610, 1345)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 317,604
#   Valid VI pixels   : 317,604
#
# Found 1 county/county-like IDs in raster.
# Processing county 19191: NASS=66.30 bu/ac, valid VI pixels=317,604, crop pixels=317,604
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19191_Winneshiek_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19191_Winneshiek_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19191  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19191_Winneshiek_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19193_Woodbury_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19193
#   County name : Woodbury
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1311, 2260)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 793,210
#   Valid VI pixels   : 793,210
#
# Found 1 county/county-like IDs in raster.
# Processing county 19193: NASS=56.40 bu/ac, valid VI pixels=793,210, crop pixels=793,210
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19193_Woodbury_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19193_Woodbury_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19193  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19193_Woodbury_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_IA_2022_19195_Worth_vi_pixels_nasa_cmr_hls.tif
#   State       : IA
#   Year        : 2022 (auto-detected from filename)
#   County FIPS : 19195
#   County name : Worth
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (946, 1299)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'crop_mask': 10, 'valid_vi_mask': 11}
#
# Pixels:
#   Crop pixels       : 387,772
#   Valid VI pixels   : 387,772
#
# Found 1 county/county-like IDs in raster.
# Processing county 19195: NASS=62.00 bu/ac, valid VI pixels=387,772, crop pixels=387,772
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19195_Worth_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19195_Worth_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       19195  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_IA_2022_19195_Worth_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.

# %%
print("Done")
# Out:
# Done

# %%
for state in ["IA"]:
    for year in [2023, 2024]:     
        print(f"Processing state: {state}, year: {year}")   
        STATE_CODE = state
        YEAR = year

        parent_folder = Path(f"/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/{STATE_CODE}")

        tif_files = sorted(
            parent_folder.glob(
                f"soybeans_{STATE_CODE}_{YEAR}_*.tif"
            )
        )

        print(f"Tif files to process: {len(tif_files)}")
        print(tif_files)

        for tif_file in tif_files:
            # !uv run python /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/scripts/distribute_county_yield_to_pixels.py --vi-tif-path {tif_file}

print("Done")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 3
#       1 for state in ['IL', 'IN', 'KS', 'MI', 'MN', 'MO', 'ND', 'NE', 'OH', 'PA', 'SD', 'WI']:
#       2     for year in [2020, 2021, 2022, 2023, 2024]:
# ----> 3         print(f"Processing state: {state}, year: {year}", file = "/home/cholab/LabMembers/Samar/EO-based-yield-prediction/temp/pseudo_yield_distribution_log.txt")
#       4         STATE_CODE = state
#       5         YEAR = year
#       6
#
# AttributeError: 'str' object has no attribute 'write'

# %%
from pathlib import Path

log_path = "/home/cholab/LabMembers/Samar/EO-based-yield-prediction/temp/pseudo_yield_distribution_log.txt"

# Open the file once in append ("a") or write ("w") mode
with open(log_path, "a") as f:
    for state in ['WI']:
        for year in [2021, 2022, 2023, 2024]:     
            print(f"Processing state: {state}, year: {year}", file=f)   
            STATE_CODE = state
            YEAR = year

            parent_folder = Path(f"/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/county_year_wise_VI_tiff/2020-2024/{STATE_CODE}")

            tif_files = sorted(
                parent_folder.glob(
                    f"soybeans_{STATE_CODE}_{YEAR}_*.tif"
                )
            )

            print(f"Tif files to process: {len(tif_files)}", file=f)
            print(tif_files, file=f)

            for tif_file in tif_files:
                # !uv run python /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/scripts/distribute_county_yield_to_pixels.py --vi-tif-path {tif_file}

    print("Done", file=f)
# Out:
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55001_ADAMS_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55001
#   County name : ADAMS
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2259, 1155)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 92,953
#   Valid VI pixels   : 92,953
#
# Found 7 county/county-like IDs in raster.
# Processing county 55001: NASS=52.60 bu/ac, valid VI pixels=56,730, crop pixels=56,730
# Processing county 55021: NASS=60.90 bu/ac, valid VI pixels=351, crop pixels=351
# Processing county 55057: NASS=47.70 bu/ac, valid VI pixels=29,999, crop pixels=29,999
# Processing county 55077: NASS=48.60 bu/ac, valid VI pixels=1,349, crop pixels=1,349
# Skipping county 55097: only 5 valid VI pixels.
# Processing county 55137: NASS=52.50 bu/ac, valid VI pixels=3,512, crop pixels=3,512
# Processing county 55141: NASS=50.70 bu/ac, valid VI pixels=1,007, crop pixels=1,007
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55001_ADAMS_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55001_ADAMS_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55001  ...               0.000000e+00
# 1       55021  ...              -1.421085e-14
# 2       55057  ...               7.105427e-15
# 3       55077  ...              -7.105427e-15
# 4       55137  ...               0.000000e+00
# 5       55141  ...               7.105427e-15
#
# [6 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55001_ADAMS_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55003_ASHLAND_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55003
#   County name : ASHLAND
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (3945, 1634)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 6,565
#   Valid VI pixels   : 6,565
#
# Found 3 county/county-like IDs in raster.
# Skipping county 55003: 'No NASS yield found for GEOID=55003, year=2021'
# Processing county 55007: NASS=41.60 bu/ac, valid VI pixels=493, crop pixels=493
# Skipping county 55051: 'No NASS yield found for GEOID=55051, year=2021'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55003_ASHLAND_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55003_ASHLAND_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55007  ...              -7.105427e-15
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55003_ASHLAND_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55005_BARRON_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55005
#   County name : BARRON
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1653, 1658)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 251,544
#   Valid VI pixels   : 251,524
#
# Found 7 county/county-like IDs in raster.
# Processing county 55005: NASS=52.00 bu/ac, valid VI pixels=242,111, crop pixels=242,131
# Skipping county 55013: only 8 valid VI pixels.
# Processing county 55017: NASS=52.20 bu/ac, valid VI pixels=2,117, crop pixels=2,117
# Processing county 55033: NASS=54.20 bu/ac, valid VI pixels=2,945, crop pixels=2,945
# Processing county 55095: NASS=51.40 bu/ac, valid VI pixels=2,626, crop pixels=2,626
# Processing county 55107: NASS=46.50 bu/ac, valid VI pixels=827, crop pixels=827
# Processing county 55129: NASS=46.90 bu/ac, valid VI pixels=890, crop pixels=890
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55005_BARRON_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55005_BARRON_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55005  ...               1.421085e-14
# 1       55017  ...              -7.105427e-15
# 2       55033  ...               7.105427e-15
# 3       55095  ...              -1.421085e-14
# 4       55107  ...               0.000000e+00
# 5       55129  ...               0.000000e+00
#
# [6 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55005_BARRON_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55007_BAYFIELD_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55007
#   County name : BAYFIELD
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2906, 1903)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 13,814
#   Valid VI pixels   : 13,814
#
# Found 3 county/county-like IDs in raster.
# Skipping county 55003: 'No NASS yield found for GEOID=55003, year=2021'
# Processing county 55007: NASS=41.60 bu/ac, valid VI pixels=9,655, crop pixels=9,655
# Skipping county 55031: only 3 valid VI pixels.
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55007_BAYFIELD_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55007_BAYFIELD_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55007  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55007_BAYFIELD_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55009_BROWN_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55009
#   County name : BROWN
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1651, 1387)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 154,420
#   Valid VI pixels   : 154,417
#
# Found 7 county/county-like IDs in raster.
# Processing county 55009: NASS=49.90 bu/ac, valid VI pixels=102,612, crop pixels=102,615
# Processing county 55015: NASS=55.80 bu/ac, valid VI pixels=118, crop pixels=118
# Processing county 55061: NASS=55.80 bu/ac, valid VI pixels=4,970, crop pixels=4,970
# Processing county 55071: NASS=59.30 bu/ac, valid VI pixels=14,315, crop pixels=14,315
# Processing county 55083: NASS=49.90 bu/ac, valid VI pixels=2,077, crop pixels=2,077
# Processing county 55087: NASS=51.60 bu/ac, valid VI pixels=27,252, crop pixels=27,252
# Processing county 55115: NASS=53.00 bu/ac, valid VI pixels=3,073, crop pixels=3,073
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55009_BROWN_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55009_BROWN_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55009  ...               0.000000e+00
# 1       55015  ...               7.105427e-15
# 2       55061  ...               0.000000e+00
# 3       55071  ...              -1.421085e-14
# 4       55083  ...              -7.105427e-15
# 5       55087  ...               7.105427e-15
# 6       55115  ...               0.000000e+00
#
# [7 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55009_BROWN_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55011_BUFFALO_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55011
#   County name : BUFFALO
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1950, 1471)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 171,806
#   Valid VI pixels   : 171,806
#
# Found 4 county/county-like IDs in raster.
# Processing county 55011: NASS=51.10 bu/ac, valid VI pixels=156,068, crop pixels=156,068
# Skipping county 55035: only 8 valid VI pixels.
# Processing county 55091: NASS=55.60 bu/ac, valid VI pixels=6,478, crop pixels=6,478
# Processing county 55121: NASS=51.40 bu/ac, valid VI pixels=9,252, crop pixels=9,252
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55011_BUFFALO_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55011_BUFFALO_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55011  ...               0.000000e+00
# 1       55091  ...               1.421085e-14
# 2       55121  ...               7.105427e-15
#
# [3 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55011_BUFFALO_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55013_BURNETT_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55013
#   County name : BURNETT
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1963, 2143)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 55,554
#   Valid VI pixels   : 55,554
#
# Found 4 county/county-like IDs in raster.
# Processing county 55005: NASS=52.00 bu/ac, valid VI pixels=27, crop pixels=27
# Processing county 55013: NASS=38.20 bu/ac, valid VI pixels=46,775, crop pixels=46,775
# Processing county 55095: NASS=51.40 bu/ac, valid VI pixels=7,961, crop pixels=7,961
# Processing county 55129: NASS=46.90 bu/ac, valid VI pixels=791, crop pixels=791
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55013_BURNETT_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55013_BURNETT_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55005  ...               7.105427e-15
# 1       55013  ...               7.105427e-15
# 2       55095  ...               0.000000e+00
# 3       55129  ...              -7.105427e-15
#
# [4 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55013_BURNETT_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55015_CALUMET_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55015
#   County name : CALUMET
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1315, 1024)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 125,455
#   Valid VI pixels   : 125,452
#
# Found 6 county/county-like IDs in raster.
# Processing county 55009: NASS=49.90 bu/ac, valid VI pixels=298, crop pixels=298
# Processing county 55015: NASS=55.80 bu/ac, valid VI pixels=112,389, crop pixels=112,391
# Processing county 55039: NASS=59.20 bu/ac, valid VI pixels=7,679, crop pixels=7,679
# Processing county 55071: NASS=59.30 bu/ac, valid VI pixels=3,446, crop pixels=3,447
# Processing county 55087: NASS=51.60 bu/ac, valid VI pixels=1,415, crop pixels=1,415
# Processing county 55117: NASS=53.70 bu/ac, valid VI pixels=225, crop pixels=225
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55015_CALUMET_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55015_CALUMET_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55009  ...               7.105427e-15
# 1       55015  ...               0.000000e+00
# 2       55039  ...               0.000000e+00
# 3       55071  ...              -1.421085e-14
# 4       55087  ...               0.000000e+00
# 5       55117  ...               0.000000e+00
#
# [6 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55015_CALUMET_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55017_CHIPPEWA_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55017
#   County name : CHIPPEWA
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1704, 2002)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 313,062
#   Valid VI pixels   : 313,062
#
# Found 7 county/county-like IDs in raster.
# Processing county 55005: NASS=52.00 bu/ac, valid VI pixels=11,984, crop pixels=11,984
# Processing county 55017: NASS=52.20 bu/ac, valid VI pixels=282,954, crop pixels=282,954
# Processing county 55019: NASS=50.90 bu/ac, valid VI pixels=503, crop pixels=503
# Processing county 55033: NASS=54.20 bu/ac, valid VI pixels=6,080, crop pixels=6,080
# Processing county 55035: NASS=53.20 bu/ac, valid VI pixels=3,891, crop pixels=3,891
# Processing county 55107: NASS=46.50 bu/ac, valid VI pixels=1,753, crop pixels=1,753
# Processing county 55119: NASS=52.90 bu/ac, valid VI pixels=5,897, crop pixels=5,897
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55017_CHIPPEWA_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55017_CHIPPEWA_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55005  ...               0.000000e+00
# 1       55017  ...               0.000000e+00
# 2       55019  ...               0.000000e+00
# 3       55033  ...               0.000000e+00
# 4       55035  ...               0.000000e+00
# 5       55107  ...               0.000000e+00
# 6       55119  ...               7.105427e-15
#
# [7 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55017_CHIPPEWA_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55019_CLARK_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55019
#   County name : CLARK
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2328, 1708)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 297,651
#   Valid VI pixels   : 297,649
#
# Found 7 county/county-like IDs in raster.
# Processing county 55017: NASS=52.20 bu/ac, valid VI pixels=839, crop pixels=839
# Processing county 55019: NASS=50.90 bu/ac, valid VI pixels=255,102, crop pixels=255,103
# Processing county 55035: NASS=53.20 bu/ac, valid VI pixels=439, crop pixels=439
# Processing county 55053: NASS=51.90 bu/ac, valid VI pixels=22,657, crop pixels=22,657
# Processing county 55073: NASS=49.80 bu/ac, valid VI pixels=13,119, crop pixels=13,120
# Processing county 55119: NASS=52.90 bu/ac, valid VI pixels=3,938, crop pixels=3,938
# Processing county 55141: NASS=50.70 bu/ac, valid VI pixels=1,555, crop pixels=1,555
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55019_CLARK_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55019_CLARK_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55017  ...               0.000000e+00
# 1       55019  ...              -7.105427e-15
# 2       55035  ...              -7.105427e-15
# 3       55053  ...              -7.105427e-15
# 4       55073  ...               0.000000e+00
# 5       55119  ...               7.105427e-15
# 6       55141  ...               0.000000e+00
#
# [7 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55019_CLARK_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55021_COLUMBIA_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55021
#   County name : COLUMBIA
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1403, 2146)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 314,970
#   Valid VI pixels   : 314,965
#
# Found 7 county/county-like IDs in raster.
# Processing county 55001: NASS=52.60 bu/ac, valid VI pixels=5,173, crop pixels=5,173
# Processing county 55021: NASS=60.90 bu/ac, valid VI pixels=251,271, crop pixels=251,275
# Processing county 55025: NASS=62.90 bu/ac, valid VI pixels=12,122, crop pixels=12,122
# Processing county 55027: NASS=62.90 bu/ac, valid VI pixels=6,711, crop pixels=6,711
# Processing county 55047: NASS=56.20 bu/ac, valid VI pixels=1,026, crop pixels=1,026
# Processing county 55077: NASS=48.60 bu/ac, valid VI pixels=3,276, crop pixels=3,276
# Processing county 55111: NASS=54.60 bu/ac, valid VI pixels=35,386, crop pixels=35,387
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55021_COLUMBIA_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55021_COLUMBIA_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55001  ...              -7.105427e-15
# 1       55021  ...              -7.105427e-15
# 2       55025  ...              -1.421085e-14
# 3       55027  ...               7.105427e-15
# 4       55047  ...              -7.105427e-15
# 5       55077  ...               0.000000e+00
# 6       55111  ...               7.105427e-15
#
# [7 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55021_COLUMBIA_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55023_CRAWFORD_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55023
#   County name : CRAWFORD
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1623, 1496)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 109,229
#   Valid VI pixels   : 109,229
#
# Found 4 county/county-like IDs in raster.
# Processing county 55023: NASS=54.80 bu/ac, valid VI pixels=94,959, crop pixels=94,959
# Processing county 55043: NASS=62.90 bu/ac, valid VI pixels=9,883, crop pixels=9,883
# Processing county 55103: NASS=48.30 bu/ac, valid VI pixels=616, crop pixels=616
# Processing county 55123: NASS=53.90 bu/ac, valid VI pixels=3,771, crop pixels=3,771
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55023_CRAWFORD_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55023_CRAWFORD_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55023  ...              -7.105427e-15
# 1       55043  ...               7.105427e-15
# 2       55103  ...               0.000000e+00
# 3       55123  ...              -7.105427e-15
#
# [4 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55023_CRAWFORD_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55025_DANE_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55025
#   County name : DANE
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1739, 2305)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 476,085
#   Valid VI pixels   : 476,064
#
# Found 8 county/county-like IDs in raster.
# Processing county 55021: NASS=60.90 bu/ac, valid VI pixels=14,188, crop pixels=14,188
# Processing county 55025: NASS=62.90 bu/ac, valid VI pixels=416,872, crop pixels=416,892
# Processing county 55027: NASS=62.90 bu/ac, valid VI pixels=4,303, crop pixels=4,303
# Processing county 55045: NASS=60.00 bu/ac, valid VI pixels=6,516, crop pixels=6,516
# Processing county 55049: NASS=61.30 bu/ac, valid VI pixels=4,055, crop pixels=4,055
# Processing county 55055: NASS=58.00 bu/ac, valid VI pixels=9,695, crop pixels=9,695
# Processing county 55105: NASS=56.90 bu/ac, valid VI pixels=14,791, crop pixels=14,791
# Processing county 55111: NASS=54.60 bu/ac, valid VI pixels=5,644, crop pixels=5,645
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55025_DANE_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55025_DANE_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55021  ...              -7.105427e-15
# 1       55025  ...               0.000000e+00
# 2       55027  ...               7.105427e-15
# 3       55045  ...               0.000000e+00
# 4       55049  ...               0.000000e+00
# 5       55055  ...               0.000000e+00
# 6       55105  ...              -7.105427e-15
# 7       55111  ...               0.000000e+00
#
# [8 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55025_DANE_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55027_DODGE_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55027
#   County name : DODGE
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1729, 1700)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 468,972
#   Valid VI pixels   : 468,968
#
# Found 8 county/county-like IDs in raster.
# Processing county 55021: NASS=60.90 bu/ac, valid VI pixels=10,333, crop pixels=10,333
# Processing county 55025: NASS=62.90 bu/ac, valid VI pixels=7,210, crop pixels=7,210
# Processing county 55027: NASS=62.90 bu/ac, valid VI pixels=418,580, crop pixels=418,583
# Processing county 55039: NASS=59.20 bu/ac, valid VI pixels=10,377, crop pixels=10,377
# Processing county 55047: NASS=56.20 bu/ac, valid VI pixels=4,886, crop pixels=4,886
# Processing county 55055: NASS=58.00 bu/ac, valid VI pixels=8,056, crop pixels=8,056
# Processing county 55131: NASS=53.90 bu/ac, valid VI pixels=4,739, crop pixels=4,739
# Processing county 55133: NASS=52.50 bu/ac, valid VI pixels=4,787, crop pixels=4,788
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55027_DODGE_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55027_DODGE_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55021  ...               0.000000e+00
# 1       55025  ...               0.000000e+00
# 2       55027  ...               0.000000e+00
# 3       55039  ...              -1.421085e-14
# 4       55047  ...              -1.421085e-14
# 5       55055  ...               0.000000e+00
# 6       55131  ...               0.000000e+00
# 7       55133  ...              -1.421085e-14
#
# [8 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55027_DODGE_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55029_DOOR_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55029
#   County name : DOOR
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2930, 2146)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 75,943
#   Valid VI pixels   : 75,943
#
# Found 3 county/county-like IDs in raster.
# Processing county 55029: NASS=50.80 bu/ac, valid VI pixels=72,698, crop pixels=72,698
# Processing county 55061: NASS=55.80 bu/ac, valid VI pixels=2,672, crop pixels=2,672
# Processing county 55075: NASS=48.80 bu/ac, valid VI pixels=573, crop pixels=573
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55029_DOOR_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55029_DOOR_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55029  ...              -7.105427e-15
# 1       55061  ...              -7.105427e-15
# 2       55075  ...              -7.105427e-15
#
# [3 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55029_DOOR_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55031_county_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55031
#   County name : county
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2097, 1914)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 793
#   Valid VI pixels   : 793
#
# Found 3 county/county-like IDs in raster.
# Processing county 55007: NASS=41.60 bu/ac, valid VI pixels=14, crop pixels=14
# Skipping county 55031: 'No NASS yield found for GEOID=55031, year=2021'
# Processing county 55129: NASS=46.90 bu/ac, valid VI pixels=11, crop pixels=11
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55031_county_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55031_county_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55007  ...               7.105427e-15
# 1       55129  ...               0.000000e+00
#
# [2 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55031_county_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55033_DUNN_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55033
#   County name : DUNN
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1992, 1405)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 336,134
#   Valid VI pixels   : 336,133
#
# Found 7 county/county-like IDs in raster.
# Processing county 55005: NASS=52.00 bu/ac, valid VI pixels=3,951, crop pixels=3,951
# Processing county 55017: NASS=52.20 bu/ac, valid VI pixels=13,008, crop pixels=13,008
# Processing county 55033: NASS=54.20 bu/ac, valid VI pixels=296,096, crop pixels=296,097
# Processing county 55035: NASS=53.20 bu/ac, valid VI pixels=524, crop pixels=524
# Processing county 55091: NASS=55.60 bu/ac, valid VI pixels=2,363, crop pixels=2,363
# Processing county 55093: NASS=55.80 bu/ac, valid VI pixels=10,204, crop pixels=10,204
# Processing county 55109: NASS=52.20 bu/ac, valid VI pixels=9,987, crop pixels=9,987
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55033_DUNN_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55033_DUNN_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55005  ...               0.000000e+00
# 1       55017  ...               7.105427e-15
# 2       55033  ...               7.105427e-15
# 3       55035  ...               0.000000e+00
# 4       55091  ...              -7.105427e-15
# 5       55093  ...               0.000000e+00
# 6       55109  ...              -1.421085e-14
#
# [7 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55033_DUNN_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# usage: distribute_county_yield_to_pixels.py [-h] [--vi-tif-path VI_TIF_PATH]
# distribute_county_yield_to_pixels.py: error: unrecognized arguments: CLAIRE_vi_pixels_nasa_cmr_hls.tif
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55037_county_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55037
#   County name : county
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1060, 1648)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 1,789
#   Valid VI pixels   : 1,789
#
# Found 3 county/county-like IDs in raster.
# Skipping county 55037: 'No NASS yield found for GEOID=55037, year=2021'
# Skipping county 55041: only 4 valid VI pixels.
# Processing county 55075: NASS=48.80 bu/ac, valid VI pixels=20, crop pixels=20
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55037_county_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55037_county_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55075  ...                        0.0
#
# [1 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55037_county_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# usage: distribute_county_yield_to_pixels.py [-h] [--vi-tif-path VI_TIF_PATH]
# distribute_county_yield_to_pixels.py: error: unrecognized arguments: DU LAC_vi_pixels_nasa_cmr_hls.tif
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55041_FOREST_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55041
#   County name : FOREST
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2410, 1732)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 2,455
#   Valid VI pixels   : 2,455
#
# Found 7 county/county-like IDs in raster.
# Skipping county 55037: 'No NASS yield found for GEOID=55037, year=2021'
# Skipping county 55041: 'No NASS yield found for GEOID=55041, year=2021'
# Processing county 55067: NASS=50.20 bu/ac, valid VI pixels=30, crop pixels=30
# Processing county 55075: NASS=48.80 bu/ac, valid VI pixels=32, crop pixels=32
# Skipping county 55083: only 1 valid VI pixels.
# Skipping county 55085: 'No NASS yield found for GEOID=55085, year=2021'
# Skipping county 55125: 'No NASS yield found for GEOID=55125, year=2021'
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55041_FOREST_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55041_FOREST_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55067  ...               7.105427e-15
# 1       55075  ...               0.000000e+00
#
# [2 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55041_FOREST_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2021_55043_GRANT_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2021 (auto-detected from filename)
#   County FIPS : 55043
#   County name : GRANT
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (2594, 2034)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 384,312
#   Valid VI pixels   : 384,311
#
# Found 5 county/county-like IDs in raster.
# Processing county 55023: NASS=54.80 bu/ac, valid VI pixels=40,743, crop pixels=40,743
# Processing county 55043: NASS=62.90 bu/ac, valid VI pixels=319,425, crop pixels=319,426
# Processing county 55049: NASS=61.30 bu/ac, valid VI pixels=15,672, crop pixels=15,672
# Processing county 55065: NASS=63.50 bu/ac, valid VI pixels=7,316, crop pixels=7,316
# Processing county 55103: NASS=48.30 bu/ac, valid VI pixels=1,155, crop pixels=1,155
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55043_GRANT_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2021_55043_GRANT_pseudo_yield_county_diagnostics.csv
#
# ...
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55001  ...               0.000000e+00
# 1       55047  ...              -7.105427e-15
# 2       55077  ...               3.552714e-15
# 3       55097  ...               0.000000e+00
# 4       55139  ...               1.421085e-14
#
# [5 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55137_WAUSHARA_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2024_55139_WINNEBAGO_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2024 (auto-detected from filename)
#   County FIPS : 55139
#   County name : WINNEBAGO
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1368, 1194)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 186,246
#   Valid VI pixels   : 186,246
#
# Found 6 county/county-like IDs in raster.
# Processing county 55039: NASS=52.40 bu/ac, valid VI pixels=7,746, crop pixels=7,746
# Processing county 55047: NASS=50.10 bu/ac, valid VI pixels=5,202, crop pixels=5,202
# Processing county 55087: NASS=49.40 bu/ac, valid VI pixels=1,293, crop pixels=1,293
# Skipping county 55135: 'No NASS yield found for GEOID=55135, year=2024'
# Skipping county 55137: 'No NASS yield found for GEOID=55137, year=2024'
# Processing county 55139: NASS=46.00 bu/ac, valid VI pixels=166,278, crop pixels=166,278
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55139_WINNEBAGO_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55139_WINNEBAGO_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55039  ...              -7.105427e-15
# 1       55047  ...               7.105427e-15
# 2       55087  ...               0.000000e+00
# 3       55139  ...               0.000000e+00
#
# [4 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55139_WINNEBAGO_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2024_55141_WOOD_vi_pixels_nasa_cmr_hls.tif
#   State       : WI
#   Year        : 2024 (auto-detected from filename)
#   County FIPS : 55141
#   County name : WOOD
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (1649, 1644)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 68,443
#   Valid VI pixels   : 68,443
#
# Found 7 county/county-like IDs in raster.
# Skipping county 55001: only 1 valid VI pixels.
# Processing county 55019: NASS=39.40 bu/ac, valid VI pixels=192, crop pixels=192
# Processing county 55053: NASS=41.20 bu/ac, valid VI pixels=123, crop pixels=123
# Processing county 55057: NASS=36.70 bu/ac, valid VI pixels=38, crop pixels=38
# Processing county 55073: NASS=35.80 bu/ac, valid VI pixels=1,435, crop pixels=1,435
# Processing county 55097: NASS=45.40 bu/ac, valid VI pixels=6,145, crop pixels=6,145
# Processing county 55141: NASS=34.00 bu/ac, valid VI pixels=60,509, crop pixels=60,509
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55141_WOOD_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55141_WOOD_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#   county_fips  ...  mean_difference_from_nass
# 0       55019  ...               0.000000e+00
# 1       55053  ...               0.000000e+00
# 2       55057  ...               7.105427e-15
# 3       55073  ...               0.000000e+00
# 4       55097  ...               0.000000e+00
# 5       55141  ...               7.105427e-15
#
# [6 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_55141_WOOD_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
# warning: `VIRTUAL_ENV=/home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/.venv` does not match the project environment path `/home/cholab/LabMembers/Samar/EO-based-yield-prediction/.venv` and will be ignored; use `--active` to target the active environment instead
# Parsed input TIFF metadata:
#   File        : soybeans_WI_2024_vi_pixels.tif
#   State       : WI
#   Year        : 2024 (auto-detected from filename)
#   County FIPS : None
#   County name : None
#
# Loaded normalized VI redistribution weights:
#   NDVI_mean   : -0.40465393
#   EVI_mean    :  0.26509722
#   GCVI_mean   :  0.27473654
#   NDWI_mean   :  0.05551231
#
# Input raster details:
#   Shape : (17815, 16384)
#   CRS   : EPSG:5070
#   Bands : {'NDVI_mean': 1, 'EVI_mean': 2, 'GCVI_mean': 3, 'NDWI_mean': 4, 'county_fips': 6, 'crop_mask': 7, 'valid_vi_mask': 8}
#
# Pixels:
#   Crop pixels       : 9,797,790
#   Valid VI pixels   : 9,797,693
#
# Found 72 county/county-like IDs in raster.
# Processing county 55001: NASS=47.80 bu/ac, valid VI pixels=76,226, crop pixels=76,226
# Processing county 55003: NASS=34.90 bu/ac, valid VI pixels=7,487, crop pixels=7,487
# Processing county 55005: NASS=41.40 bu/ac, valid VI pixels=235,581, crop pixels=235,583
# Processing county 55007: NASS=29.10 bu/ac, valid VI pixels=12,389, crop pixels=12,389
# Processing county 55009: NASS=43.80 bu/ac, valid VI pixels=81,197, crop pixels=81,197
# Processing county 55011: NASS=46.40 bu/ac, valid VI pixels=148,747, crop pixels=148,747
# Processing county 55013: NASS=31.70 bu/ac, valid VI pixels=38,020, crop pixels=38,020
# Processing county 55015: NASS=52.20 bu/ac, valid VI pixels=122,960, crop pixels=122,960
# Processing county 55017: NASS=43.10 bu/ac, valid VI pixels=286,940, crop pixels=286,940
# Processing county 55019: NASS=39.40 bu/ac, valid VI pixels=227,941, crop pixels=227,941
# Processing county 55021: NASS=58.00 bu/ac, valid VI pixels=259,766, crop pixels=259,766
# Processing county 55023: NASS=46.80 bu/ac, valid VI pixels=86,696, crop pixels=86,696
# Processing county 55025: NASS=54.20 bu/ac, valid VI pixels=416,028, crop pixels=416,029
# Processing county 55027: NASS=55.70 bu/ac, valid VI pixels=422,212, crop pixels=422,213
# Processing county 55029: NASS=32.20 bu/ac, valid VI pixels=70,239, crop pixels=70,239
# Skipping county 55031: 'No NASS yield found for GEOID=55031, year=2024'
# Processing county 55033: NASS=42.80 bu/ac, valid VI pixels=287,789, crop pixels=287,796
# Processing county 55035: NASS=42.70 bu/ac, valid VI pixels=145,150, crop pixels=145,150
# Skipping county 55037: 'No NASS yield found for GEOID=55037, year=2024'
# Processing county 55039: NASS=52.40 bu/ac, valid VI pixels=280,037, crop pixels=280,038
# Skipping county 55041: 'No NASS yield found for GEOID=55041, year=2024'
# Processing county 55043: NASS=58.80 bu/ac, valid VI pixels=377,358, crop pixels=377,358
# Skipping county 55045: 'No NASS yield found for GEOID=55045, year=2024'
# Processing county 55047: NASS=50.10 bu/ac, valid VI pixels=93,565, crop pixels=93,565
# Processing county 55049: NASS=58.50 bu/ac, valid VI pixels=211,741, crop pixels=211,741
# Skipping county 55051: 'No NASS yield found for GEOID=55051, year=2024'
# Processing county 55053: NASS=41.20 bu/ac, valid VI pixels=147,292, crop pixels=147,292
# Processing county 55055: NASS=49.60 bu/ac, valid VI pixels=255,067, crop pixels=255,067
# Processing county 55057: NASS=36.70 bu/ac, valid VI pixels=108,388, crop pixels=108,388
# Processing county 55059: NASS=47.70 bu/ac, valid VI pixels=117,884, crop pixels=117,890
# Processing county 55061: NASS=44.90 bu/ac, valid VI pixels=62,280, crop pixels=62,280
# Skipping county 55063: 'No NASS yield found for GEOID=55063, year=2024'
# Processing county 55065: NASS=58.50 bu/ac, valid VI pixels=312,287, crop pixels=312,287
# Processing county 55067: NASS=37.10 bu/ac, valid VI pixels=32,755, crop pixels=32,755
# Processing county 55069: NASS=33.50 bu/ac, valid VI pixels=29,552, crop pixels=29,552
# Processing county 55071: NASS=50.20 bu/ac, valid VI pixels=145,216, crop pixels=145,218
# Processing county 55073: NASS=35.80 bu/ac, valid VI pixels=243,670, crop pixels=243,670
# Processing county 55075: NASS=36.00 bu/ac, valid VI pixels=37,069, crop pixels=37,069
# Processing county 55077: NASS=31.60 bu/ac, valid VI pixels=73,972, crop pixels=73,972
# Skipping county 55078: 'No NASS yield found for GEOID=55078, year=2024'
# Skipping county 55079: 'No NASS yield found for GEOID=55079, year=2024'
# Skipping county 55081: 'No NASS yield found for GEOID=55081, year=2024'
# Processing county 55083: NASS=43.10 bu/ac, valid VI pixels=129,738, crop pixels=129,738
# Skipping county 55085: 'No NASS yield found for GEOID=55085, year=2024'
# Processing county 55087: NASS=49.40 bu/ac, valid VI pixels=193,354, crop pixels=193,354
# Processing county 55089: NASS=44.40 bu/ac, valid VI pixels=54,664, crop pixels=54,664
# Processing county 55091: NASS=52.50 bu/ac, valid VI pixels=79,434, crop pixels=79,434
# Processing county 55093: NASS=49.60 bu/ac, valid VI pixels=223,079, crop pixels=223,079
# Processing county 55095: NASS=41.80 bu/ac, valid VI pixels=167,395, crop pixels=167,395
# Processing county 55097: NASS=45.40 bu/ac, valid VI pixels=93,058, crop pixels=93,058
# Processing county 55099: NASS=32.70 bu/ac, valid VI pixels=4,456, crop pixels=4,456
# Processing county 55101: NASS=45.90 bu/ac, valid VI pixels=151,791, crop pixels=151,866
# Processing county 55103: NASS=45.00 bu/ac, valid VI pixels=68,577, crop pixels=68,577
# Processing county 55105: NASS=56.30 bu/ac, valid VI pixels=441,889, crop pixels=441,889
# Processing county 55107: NASS=36.20 bu/ac, valid VI pixels=72,353, crop pixels=72,353
# Processing county 55109: NASS=49.90 bu/ac, valid VI pixels=256,106, crop pixels=256,106
# Processing county 55111: NASS=47.20 bu/ac, valid VI pixels=170,675, crop pixels=170,675
# Processing county 55113: NASS=36.00 bu/ac, valid VI pixels=15,961, crop pixels=15,961
# Skipping county 55115: 'No NASS yield found for GEOID=55115, year=2024'
# Processing county 55117: NASS=42.40 bu/ac, valid VI pixels=158,739, crop pixels=158,739
# Processing county 55119: NASS=34.40 bu/ac, valid VI pixels=115,634, crop pixels=115,634
# Processing county 55121: NASS=45.90 bu/ac, valid VI pixels=193,340, crop pixels=193,340
# Skipping county 55123: 'No NASS yield found for GEOID=55123, year=2024'
# Skipping county 55125: 'No NASS yield found for GEOID=55125, year=2024'
# Processing county 55127: NASS=52.10 bu/ac, valid VI pixels=266,287, crop pixels=266,287
# Processing county 55129: NASS=35.10 bu/ac, valid VI pixels=35,196, crop pixels=35,196
# Processing county 55131: NASS=44.90 bu/ac, valid VI pixels=108,359, crop pixels=108,359
# Processing county 55133: NASS=47.70 bu/ac, valid VI pixels=76,568, crop pixels=76,568
# Skipping county 55135: 'No NASS yield found for GEOID=55135, year=2024'
# Skipping county 55137: 'No NASS yield found for GEOID=55137, year=2024'
# Processing county 55139: NASS=46.00 bu/ac, valid VI pixels=166,278, crop pixels=166,278
# Processing county 55141: NASS=34.00 bu/ac, valid VI pixels=60,509, crop pixels=60,509
#
# Saved outputs:
#   Pseudo-yield TIFF      : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_pseudo_yield.tif
#   County diagnostics CSV : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_pseudo_yield_county_diagnostics.csv
#
# County mean preservation check:
#    county_fips  ...  mean_difference_from_nass
# 0        55001  ...               0.000000e+00
# 1        55003  ...               0.000000e+00
# 2        55005  ...               0.000000e+00
# 3        55007  ...               0.000000e+00
# 4        55009  ...               0.000000e+00
# 5        55011  ...              -7.105427e-15
# 6        55013  ...               0.000000e+00
# 7        55015  ...               7.105427e-15
# 8        55017  ...               0.000000e+00
# 9        55019  ...               0.000000e+00
# 10       55021  ...               0.000000e+00
# 11       55023  ...               0.000000e+00
# 12       55025  ...              -7.105427e-15
# 13       55027  ...               0.000000e+00
# 14       55029  ...              -7.105427e-15
# 15       55033  ...              -7.105427e-15
# 16       55035  ...               0.000000e+00
# 17       55039  ...               7.105427e-15
# 18       55043  ...               0.000000e+00
# 19       55047  ...               0.000000e+00
# 20       55049  ...               0.000000e+00
# 21       55053  ...               0.000000e+00
# 22       55055  ...              -7.105427e-15
# 23       55057  ...               0.000000e+00
# 24       55059  ...               7.105427e-15
# 25       55061  ...               0.000000e+00
# 26       55065  ...               0.000000e+00
# 27       55067  ...               7.105427e-15
# 28       55069  ...               0.000000e+00
# 29       55071  ...               0.000000e+00
# 30       55073  ...               0.000000e+00
# 31       55075  ...              -7.105427e-15
# 32       55077  ...               0.000000e+00
# 33       55083  ...               7.105427e-15
# 34       55087  ...              -7.105427e-15
# 35       55089  ...               0.000000e+00
# 36       55091  ...              -1.421085e-14
# 37       55093  ...               7.105427e-15
# 38       55095  ...               0.000000e+00
# 39       55097  ...               0.000000e+00
# 40       55099  ...               0.000000e+00
# 41       55101  ...               0.000000e+00
# 42       55103  ...               7.105427e-15
# 43       55105  ...              -7.105427e-15
# 44       55107  ...               7.105427e-15
# 45       55109  ...               0.000000e+00
# 46       55111  ...              -7.105427e-15
# 47       55113  ...               0.000000e+00
# 48       55117  ...               0.000000e+00
# 49       55119  ...               0.000000e+00
# 50       55121  ...               0.000000e+00
# 51       55127  ...               7.105427e-15
# 52       55129  ...               7.105427e-15
# 53       55131  ...               0.000000e+00
# 54       55133  ...              -7.105427e-15
# 55       55139  ...               0.000000e+00
# 56       55141  ...               7.105427e-15
#
# [57 rows x 4 columns]
#   Plot saved             : /home/cholab/LabMembers/Samar/EO-based-yield-prediction/data_preparation/data/pixel_distributed_yield/Intermediate/soybeans_WI_2024_pseudo_yield_comparison.png
# Figure(1600x700)
#
# ✓ Script complete.
